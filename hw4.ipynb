# %%
import pandas as pd
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
print(df_krx.head())
# Out:
#      Code        ISU_CD      Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI         57600          2    -1200
# 1  000660  KR7000660001    SK하이닉스  KOSPI        194600          2    -3300
# 2  207940  KR7207940008  삼성바이오로직스  KOSPI       1113000          1    63000
# 3  373220  KR7373220003  LG에너지솔루션  KOSPI        315000          2   -14000
# 4  005380  KR7005380001       현대차  KOSPI        193800          2    -2500
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# 0        -2.04    56900    57800    56900  19508076  1118162896800
# 1        -1.67   189600   194600   188200   4177747   802393786600
# 2         6.00  1035000  1127000  1035000    141538   156903525000
# 3        -4.26   320000   323000   310500    388422   122716732000
# 4        -1.27   191000   194500   189100    954824   183788412750
#
#             Marcap      Stocks MarketId
# 0  340971144307200  5919637922      STK
# ...

# %%
import pandas as pd
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
print(df_krx.head())
df_selected = df_krx[['Code', 'Name', 'Marcap', 'Stocks', 'MarketId']]
print(df_selected.head())
df_samsung = df_selected[df_selected['Name'].str.startswith('삼성')]
print(df_samsung)
df_samsung_special = df_samsung[df_samsung['Name'].str.contains('우|스팩', na=False, regex=True)]
print(df_samsung_special)
df_samsung_filtered = df_samsung.drop(df_samsung_special.index)
print(df_samsung_filtered)
# Out:
#      Code        ISU_CD      Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI         57600          2    -1200
# 1  000660  KR7000660001    SK하이닉스  KOSPI        194600          2    -3300
# 2  207940  KR7207940008  삼성바이오로직스  KOSPI       1113000          1    63000
# 3  373220  KR7373220003  LG에너지솔루션  KOSPI        315000          2   -14000
# 4  005380  KR7005380001       현대차  KOSPI        193800          2    -2500
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# 0        -2.04    56900    57800    56900  19508076  1118162896800
# 1        -1.67   189600   194600   188200   4177747   802393786600
# 2         6.00  1035000  1127000  1035000    141538   156903525000
# 3        -4.26   320000   323000   310500    388422   122716732000
# 4        -1.27   191000   194500   189100    954824   183788412750
#
#             Marcap      Stocks MarketId
# 0  340971144307200  5919637922      STK
# ...

# %%
import pandas as pd
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
print(df_krx.head())
df_selected = df_krx[['Code', 'Name', 'Marcap', 'Stocks', 'MarketId']]
print(df_selected.head())
df_samsung = df_selected[df_selected['Name'].str.startswith('삼성')]
print(df_samsung)
df_samsung_special = df_samsung[df_samsung['Name'].str.contains('우|스팩', na=False, regex=True)]
print(df_samsung_special)
df_samsung_filtered = df_samsung.drop(df_samsung_special.index)
print(df_samsung_filtered)
output_path = "202331107_강현우.xlsx"
df_samsung_filtered.to_excel(output_path, index=False)
# Out:
#      Code        ISU_CD      Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI         57600          2    -1200
# 1  000660  KR7000660001    SK하이닉스  KOSPI        194600          2    -3300
# 2  207940  KR7207940008  삼성바이오로직스  KOSPI       1113000          1    63000
# 3  373220  KR7373220003  LG에너지솔루션  KOSPI        315000          2   -14000
# 4  005380  KR7005380001       현대차  KOSPI        193800          2    -2500
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# 0        -2.04    56900    57800    56900  19508076  1118162896800
# 1        -1.67   189600   194600   188200   4177747   802393786600
# 2         6.00  1035000  1127000  1035000    141538   156903525000
# 3        -4.26   320000   323000   310500    388422   122716732000
# 4        -1.27   191000   194500   189100    954824   183788412750
#
#             Marcap      Stocks MarketId
# 0  340971144307200  5919637922      STK
# ...

# %%
import pandas as pd
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
print(df_krx.head())
df_selected = df_krx[['Code', 'Name', 'Marcap', 'Stocks', 'MarketId']]
print(df_selected.head())
df_samsung = df_selected[df_selected['Name'].str.startswith('삼성')]
print(df_samsung)
df_samsung_special = df_samsung[df_samsung['Name'].str.contains('우|스팩', na=False, regex=True)]
print(df_samsung_special)
df_samsung_filtered = df_samsung.drop(df_samsung_special.index)
print(df_samsung_filtered)
output_path = "202331107_강현우.xlsx"
df_samsung_filtered.to_excel(output_path, index=False)
print("{os.path.abspath(output_path)}")
# Out:
#      Code        ISU_CD      Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI         57600          2    -1200
# 1  000660  KR7000660001    SK하이닉스  KOSPI        194600          2    -3300
# 2  207940  KR7207940008  삼성바이오로직스  KOSPI       1113000          1    63000
# 3  373220  KR7373220003  LG에너지솔루션  KOSPI        315000          2   -14000
# 4  005380  KR7005380001       현대차  KOSPI        193800          2    -2500
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# 0        -2.04    56900    57800    56900  19508076  1118162896800
# 1        -1.67   189600   194600   188200   4177747   802393786600
# 2         6.00  1035000  1127000  1035000    141538   156903525000
# 3        -4.26   320000   323000   310500    388422   122716732000
# 4        -1.27   191000   194500   189100    954824   183788412750
#
#             Marcap      Stocks MarketId
# 0  340971144307200  5919637922      STK
# ...

# %%
import pandas as pd
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')
print(df_krx.head())
df_selected = df_krx[['Code', 'Name', 'Marcap', 'Stocks', 'MarketId']]
print(df_selected.head())
df_samsung = df_selected[df_selected['Name'].str.startswith('삼성')]
print(df_samsung)
df_samsung_special = df_samsung[df_samsung['Name'].str.contains('우|스팩', na=False, regex=True)]
print(df_samsung_special)
df_samsung_filtered = df_samsung.drop(df_samsung_special.index)
print(df_samsung_filtered)
output_path = "202331107_강현우.xlsx"
df_samsung_filtered.to_excel(output_path, index=False)
# Out:
#      Code        ISU_CD      Name Market Dept    Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI         57600          2    -1200
# 1  000660  KR7000660001    SK하이닉스  KOSPI        194600          2    -3300
# 2  207940  KR7207940008  삼성바이오로직스  KOSPI       1113000          1    63000
# 3  373220  KR7373220003  LG에너지솔루션  KOSPI        315000          2   -14000
# 4  005380  KR7005380001       현대차  KOSPI        193800          2    -2500
#
#    ChagesRatio     Open     High      Low    Volume         Amount  \
# 0        -2.04    56900    57800    56900  19508076  1118162896800
# 1        -1.67   189600   194600   188200   4177747   802393786600
# 2         6.00  1035000  1127000  1035000    141538   156903525000
# 3        -4.26   320000   323000   310500    388422   122716732000
# 4        -1.27   191000   194500   189100    954824   183788412750
#
#             Marcap      Stocks MarketId
# 0  340971144307200  5919637922      STK
# ...
